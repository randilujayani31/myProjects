# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from keras import models
from keras import layers

# %%
# Load the dataset
df = pd.read_csv('data.csv', delimiter=';')

# %%
# Display the first few rows to ensure it's loaded correctly
#print(df.head())
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   label               120 non-null    int64
#  1   Area(cm^2)          120 non-null    float64
#  2   W/L                 120 non-null    float64
#  3   Patiole Length(mm)  120 non-null    float64
#  4   Number of Pairs     120 non-null    int64
#  5   Ratio               120 non-null    float64
# dtypes: float64(4), int64(2)
# memory usage: 5.8 KB
# None

# %%
# Identify the target variable (assuming the column name is 'label')
target = df['label']

# %%
# Identify the feature variables (all columns except the target column)
features = df.drop(columns=['label'])

# %%
# Verify the shapes to ensure they are correct
print("Target shape:", target.shape)
print("Features shape:", features.shape)
# Out:
# Target shape: (120,)
# Features shape: (120, 5)

# %%
# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# %%
from sklearn.preprocessing import OneHotEncoder

# Initialize the OneHotEncoder with the updated parameter
encoder = OneHotEncoder(sparse_output=False)

# %%
# Fit and transform the training labels
y_train_encoded = encoder.fit_transform(y_train.values.reshape(-1, 1))

# %%
# Transform the testing labels
y_test_encoded = encoder.transform(y_test.values.reshape(-1, 1))

# %%
# Define the model
model = models.Sequential()
model.add(layers.Dense(36, activation='relu', input_shape=(x_train.shape[1],)))
model.add(layers.Dense(18,activation='relu'))
model.add(layers.Dense(9,activation='relu'))
model.add(layers.Dense(y_train_encoded.shape[1], activation='softmax'))
# Out:
# C:\Users\VOSTRO\.conda\envs\my_env\Lib\site-packages\keras\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Compile the model

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
val_epochs = 50
# Train the model
history = model.fit(x_train, y_train_encoded, epochs=val_epochs, batch_size=1, validation_split=0.2)
# Out:
# Epoch 1/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3893 - loss: 7.3911 - val_accuracy: 0.8000 - val_loss: 0.6152
# Epoch 2/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7493 - loss: 0.6217 - val_accuracy: 0.8000 - val_loss: 0.4836
# Epoch 3/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9422 - loss: 0.3463 - val_accuracy: 0.8000 - val_loss: 0.4630
# Epoch 4/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8656 - loss: 0.3256 - val_accuracy: 0.8500 - val_loss: 0.4467
# Epoch 5/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8962 - loss: 0.2797 - val_accuracy: 0.8500 - val_loss: 0.4292
# Epoch 6/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9008 - loss: 0.2325 - val_accuracy: 0.7500 - val_loss: 0.6089
# Epoch 7/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9631 - loss: 0.2028 - val_accuracy: 0.7500 - val_loss: 0.5391
# Epoch 8/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8515 - loss: 0.2550 - val_accuracy: 0.8500 - val_loss: 0.4325
# Epoch 9/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9009 - loss: 0.2237 - val_accuracy: 0.8000 - val_loss: 0.4665
# Epoch 10/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8721 - loss: 0.2934 - val_accuracy: 0.7500 - val_loss: 0.5269
# Epoch 11/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9676 - loss: 0.1623 - val_accuracy: 0.8500 - val_loss: 0.5056
# Epoch 12/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8923 - loss: 0.2172 - val_accuracy: 0.8500 - val_loss: 0.4366
# Epoch 13/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9421 - loss: 0.1495 - val_accuracy: 0.8500 - val_loss: 0.4268
# Epoch 14/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9253 - loss: 0.2061 - val_accuracy: 0.8500 - val_loss: 0.5950
# Epoch 15/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9357 - loss: 0.1813 - val_accuracy: 0.7000 - val_loss: 0.7954
# Epoch 16/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9234 - loss: 0.2139 - val_accuracy: 0.7500 - val_loss: 0.6694
# Epoch 17/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9036 - loss: 0.2303 - val_accuracy: 0.8500 - val_loss: 0.5776
# Epoch 18/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8803 - loss: 0.2861 - val_accuracy: 0.7500 - val_loss: 0.6637
# Epoch 19/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9495 - loss: 0.1419 - val_accuracy: 0.8500 - val_loss: 0.5331
# Epoch 20/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8668 - loss: 0.3033 - val_accuracy: 0.7500 - val_loss: 0.5653
# Epoch 21/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9045 - loss: 0.2753 - val_accuracy: 0.8500 - val_loss: 0.5860
# Epoch 22/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9492 - loss: 0.1638 - val_accuracy: 0.8500 - val_loss: 0.5102
# Epoch 23/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9476 - loss: 0.1677 - val_accuracy: 0.9500 - val_loss: 0.2906
# Epoch 24/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9216 - loss: 0.2042 - val_accuracy: 0.8500 - val_loss: 0.5227
# Epoch 25/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8686 - loss: 0.2965 - val_accuracy: 0.8500 - val_loss: 0.5504
# Epoch 26/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9367 - loss: 0.1224 - val_accuracy: 0.8000 - val_loss: 0.4644
# Epoch 27/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9247 - loss: 0.1902 - val_accuracy: 0.8500 - val_loss: 0.4793
# Epoch 28/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9846 - loss: 0.1212 - val_accuracy: 0.5000 - val_loss: 1.2012
# Epoch 29/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9151 - loss: 0.3454 - val_accuracy: 0.7500 - val_loss: 0.5131
# Epoch 30/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9508 - loss: 0.1252 - val_accuracy: 0.7500 - val_loss: 0.7314
# Epoch 31/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9035 - loss: 0.1743 - val_accuracy: 0.9000 - val_loss: 0.3674
# Epoch 32/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8938 - loss: 0.2488 - val_accuracy: 0.7500 - val_loss: 0.7197
# Epoch 33/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9663 - loss: 0.1493 - val_accuracy: 0.8000 - val_loss: 0.6360
# Epoch 34/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8876 - loss: 0.3298 - val_accuracy: 0.8500 - val_loss: 0.4555
# Epoch 35/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9373 - loss: 0.1514 - val_accuracy: 0.9000 - val_loss: 0.3412
# Epoch 36/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9304 - loss: 0.1503 - val_accuracy: 0.8000 - val_loss: 0.7614
# Epoch 37/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9177 - loss: 0.3920 - val_accuracy: 0.8500 - val_loss: 0.6364
# Epoch 38/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9391 - loss: 0.1084 - val_accuracy: 0.9500 - val_loss: 0.2641
# Epoch 39/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9160 - loss: 0.1861 - val_accuracy: 0.8500 - val_loss: 0.4655
# Epoch 40/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9399 - loss: 0.1492 - val_accuracy: 0.9000 - val_loss: 0.4543
# Epoch 41/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9587 - loss: 0.1417 - val_accuracy: 0.8000 - val_loss: 0.6726
# Epoch 42/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9730 - loss: 0.1444 - val_accuracy: 0.8500 - val_loss: 0.6890
# Epoch 43/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9532 - loss: 0.1660 - val_accuracy: 0.8500 - val_loss: 0.6163
# Epoch 44/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9483 - loss: 0.1365 - val_accuracy: 0.7500 - val_loss: 0.5832
# Epoch 45/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8922 - loss: 0.2500 - val_accuracy: 0.7500 - val_loss: 0.7589
# Epoch 46/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8755 - loss: 0.2055 - val_accuracy: 0.8000 - val_loss: 0.4979
# Epoch 47/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9214 - loss: 0.2205 - val_accuracy: 0.8000 - val_loss: 0.5572
# Epoch 48/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9095 - loss: 0.2098 - val_accuracy: 0.8500 - val_loss: 0.5970
# Epoch 49/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9374 - loss: 0.1358 - val_accuracy: 0.7500 - val_loss: 1.0434
# Epoch 50/50
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9488 - loss: 0.1817 - val_accuracy: 0.9000 - val_loss: 0.3819

# %%
# Evaluate the model
test_loss, test_accuracy = model.evaluate(x_test, y_test_encoded)
print(f"Test accuracy: {test_accuracy}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.9167 - loss: 0.1053
# Test accuracy: 0.9166666865348816

# %%
# Optional: Make predictions
predictions = model.predict(x_test)
print("Predictions shape:", predictions.shape)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Predictions shape: (24, 3)

# %%
history_dict = history.history
history_dict.keys()
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
import matplotlib.pyplot as plt
history_dict = history.history
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']
epochs = range(1, (val_epochs+1))
plt.plot(epochs, loss_values, 'r', label='Training loss')
plt.plot(epochs, val_loss_values, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
plt.clf()
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
plt.plot(epochs, acc, 'r', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
